# %% [markdown]
# # 2 - Census Data.
# ### Extracting a state (Mass) from the raw USA census data.

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# - Claire emailed me census data from ACS at Zipcode level
# - Open R12298078_SL860.csv in excel
#     - Delete row number 2
#     - Format Numbers (special - zipcode 5 digit) on column AQ 'Zipcode Tabulation Area'
#     - Also delete ' (5 digit)' from the header (This seems to help with importing)
# - Save and close

# %% [markdown]
# ## USZipcode python package
# - https://uszipcode.readthedocs.io/index.html

# %%
import pandas as pd
import uszipcode
print('uszipcode', uszipcode.__version__)
from uszipcode import SearchEngine, SimpleZipcode, Zipcode
# Out:
# uszipcode 0.2.2

# %%
# define a state
state = "Massachusetts"

# %%
# run the search
search = SearchEngine() # use simple_zipcode=False inside () toreturn more census data
results = search.by_state(state,returns=0) #default returns 5, 0 returns all
print ("There are", len(results), "zipcodes in", state)
# Out:
# There are 496 zipcodes in Massachusetts

# %%
temp_df = []

for entry in results:
    temp = entry.to_dict()
    temp_df.append(temp)

zipcode_results = pd.DataFrame(temp_df)

# %%
zipcode_results.columns = map(str.capitalize, zipcode_results.columns)
zipcode_results.head()
# Out:
#   Zipcode Zipcode_type   Major_city Post_office_city  \
# 0   01001     Standard       Agawam       Agawam, MA
# 1   01002     Standard      Amherst      Amherst, MA
# 2   01005     Standard        Barre        Barre, MA
# 3   01007     Standard  Belchertown  Belchertown, MA
# 4   01008     Standard    Blandford    Blandford, MA
#
#              Common_city_list            County State    Lat    Lng Timezone  \
# 0                    [Agawam]    Hampden County    MA  42.07 -72.63  Eastern
# 1  [Amherst, Cushman, Pelham]  Hampshire County    MA  42.38 -72.52  Eastern
# 2                     [Barre]  Worcester County    MA  42.42 -72.12  Eastern
# 3               [Belchertown]  Hampshire County    MA  42.30 -72.40  Eastern
# 4                 [Blandford]    Hampden County    MA  42.20 -73.00  Eastern
#
#    ...  Land_area_in_sqmi Water_area_in_sqmi  Housing_units  \
# 0  ...              11.44               0.86         7557.0
# 1  ...              55.04               1.65        10388.0
# 2  ...              44.24               0.26         2044.0
# 3  ...              52.64               2.68         5839.0
# 4  ...              53.80               1.96          586.0
#
#    Occupied_housing_units  Median_home_value  Median_household_income  \
# 0                  7215.0           213000.0                  58733.0
# 1                  9910.0           338900.0                  54422.0
# 2                  1904.0           208500.0                  68644.0
# 3                  5595.0           260000.0                  71875.0
# 4                   503.0           247200.0                  71635.0
#
#    Bounds_west  Bounds_east  Bounds_north  Bounds_south
# 0   -72.667902   -72.582535     42.100467     42.030795
# 1   -72.546776   -72.355041     42.437947     42.301437
# 2   -72.205174   -72.007388     42.484473     42.356423
# 3   -72.472287   -72.331642     42.358762     42.185812
# 4   -73.034916   -72.872180     42.251340     42.113028
#
# [5 rows x 24 columns]

# %% [markdown]
# ### Import US Census Data

# %%
usa_census = pd.read_csv('~/Desktop/new_insights/datasets/census/R12298078_SL860.csv', dtype={'ZIP Code Tabulation Area':str}, low_memory = False)

# %%
usa_census = usa_census.rename(columns={'ZIP Code Tabulation Area': 'Zipcode'})
usa_census['Zipcode']
# Out:
# 0        00601
# 1        00602
# 2        00603
# 3        00606
# 4        00610
#          ...
# 33115    99923
# 33116    99925
# 33117    99926
# 33118    99927
# 33119    99929
# Name: Zipcode, Length: 33120, dtype: object

# %%
temp_df = pd.DataFrame(zipcode_results['Zipcode'])
massachusetts_census = pd.merge(temp_df, usa_census, on = 'Zipcode')

# %%
len(massachusetts_census)
# Out:
# 485

# %%
massachusetts_census.head()
# Out:
#   Zipcode     FIPS Geographic Identifier Name of Area Qualifying Name  \
# 0   01001  1001001          86000US01001  01001 ZCTA5     01001 ZCTA5
# 1   01002  1001002          86000US01002  01002 ZCTA5     01002 ZCTA5
# 2   01005  1001005          86000US01005  01005 ZCTA5     01005 ZCTA5
# 3   01007  1001007          86000US01007  01007 ZCTA5     01007 ZCTA5
# 4   01008  1001008          86000US01008  01008 ZCTA5     01008 ZCTA5
#
#   State/U.S.-Abbreviation (USPS)  Summary Level  Geographic Component  \
# 0                             us            860                     0
# 1                             us            860                     0
# 2                             us            860                     0
# 3                             us            860                     0
# 4                             us            860                     0
#
#   File Identification  Logical Record Number  ...  \
# 0               ACSSF                  10707  ...
# 1               ACSSF                  10708  ...
# 2               ACSSF                  10710  ...
# 3               ACSSF                  10711  ...
# 4               ACSSF                  10712  ...
#
#    Own Children under 18 Years  \
# 0                         2706
# 1                         3625
# 2                          813
# 3                         3153
# 4                          181
#
#    Own Children under 18 Years: Children Living with Single Parents  \
# 0                                                627
# 1                                               1289
# 2                                                184
# 3                                                553
# 4                                                 45
#
#    Households.2  Households: 1-Person Household  \
# 0          7460                            2826
# 1          9976                            2726
# 2          1785                             503
# 3          5558                            1022
# 4           548                             122
#
#    Households: 2-Person Household  Households: 3-Person Household  \
# 0                            2460                            1010
# 1                            3185                            1632
# 2                             534                             322
# 3                            2097                             854
# 4                             236                             114
#
#    Households: 4-Person Household  Households: 5-Person Household  \
# 0                             785                             237
# 1                            1800                             455
# 2                             232                             119
# 3                            1143                             364
# 4                              58                              18
#
#    Households: 6-Person Household  Households: 7-or-More Person Household
# 0                              83                                      59
# 1                             103                                      75
# 2                              35                                      40
# 3                              78                                       0
# 4                               0                                       0
#
# [5 rows x 2200 columns]

# %%
massachusetts_census.to_csv('~/Desktop/new_insights/datasets/census/massachusetts_census_data.csv', index = False)

# %% [markdown]
# ### Double check the zipcodes thats are in the state (i.e. MA) but not in the Census Data all have population = 0.

# %%
for zip in list(zipcode_results['Zipcode']):
    if zip not in list(massachusetts_census['Zipcode']):
        print('>',zip)
# Out:
# > 01144
# > 01152
# > 01195
# > 01380
# > 01655
# > 02031
# > 02133
# > 02222
# > 02283
# > 02284
# > 02636
